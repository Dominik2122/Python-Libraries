# %%
from pandas_datareader import data
import datetime
from bokeh.plotting import figure, show, output_file
from bokeh.models.annotations import Title

# %%
start = datetime.datetime(2020,2,18)
end = datetime.datetime(2021,2,18)
df = data.DataReader(name='Goog', data_source='yahoo', start = start, end = end)
df
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-02-18  1531.630005  1512.589966  1515.000000  1519.670044  1120700
# 2020-02-19  1532.105957  1521.400024  1525.069946  1526.689941   949300
# 2020-02-20  1529.640015  1506.819946  1522.000000  1518.150024  1096600
# 2020-02-21  1512.214966  1480.439941  1508.030029  1485.109985  1731700
# 2020-02-24  1436.969971  1411.390015  1426.109985  1421.589966  2867100
# ...                 ...          ...          ...          ...      ...
# 2021-02-11  2102.030029  2077.320068  2099.510010  2095.889893   945200
# 2021-02-12  2108.820068  2083.129883  2090.250000  2104.110107   855700
# 2021-02-16  2152.679932  2104.360107  2104.360107  2121.899902  1132900
# 2021-02-17  2133.659912  2098.919922  2100.000000  2128.310059  1070100
# 2021-02-18  2132.735107  2104.280029  2110.389893  2117.199951  1035377
#
#               Adj Close
# Date
# 2020-02-18  1519.670044
# 2020-02-19  1526.689941
# 2020-02-20  1518.150024
# 2020-02-21  1485.109985
# 2020-02-24  1421.589966
# ...                 ...
# 2021-02-11  2095.889893
# 2021-02-12  2104.110107
# 2021-02-16  2121.899902
# 2021-02-17  2128.310059
# 2021-02-18  2117.199951
#
# [254 rows x 6 columns]

# %%
p=figure(x_axis_type = 'datetime', width = 1000, height = 300)
t = Title()
t.text = "Candlestick Chart"
p.title = t

hours_12 = 12*60*60*1000

p.rect(df.index[df.Close>df.Open], (df.Open+df.Close)/2, hours_12, abs(df.Open-df.Close))

output_file('cs.html')
show(p)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 143), ('y', 254)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('height', 254), ('x', 143), ('y', 254)
